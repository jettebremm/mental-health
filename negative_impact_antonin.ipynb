# %%
df = pd.read_csv('mxmh_survey_results (3).csv')
df.head(5)
# Out:
#             Timestamp   Age Primary streaming service  Hours per day  \
# 0  8/27/2022 19:29:02  18.0                   Spotify            3.0
# 1  8/27/2022 19:57:31  63.0                   Pandora            1.5
# 2  8/27/2022 21:28:18  18.0                   Spotify            4.0
# 3  8/27/2022 21:40:40  61.0             YouTube Music            2.5
# 4  8/27/2022 21:54:47  18.0                   Spotify            4.0
#
#   While working Instrumentalist Composer         Fav genre Exploratory  \
# 0           Yes             Yes      Yes             Latin         Yes
# 1           Yes              No       No              Rock         Yes
# 2            No              No       No  Video game music          No
# 3           Yes              No      Yes              Jazz         Yes
# 4           Yes              No       No               R&B         Yes
#
#   Foreign languages  ...    Frequency R&B    Frequency Rap   Frequency Rock  \
# ...

# %% [markdown]
# Using a histogram reprensents the distribution of anxiety through Jazz as fav genre

# %% [markdown]
# Using seaborn display an histogram to summarize the count of value in fav genre column

# %%
import seaborn as sns
sns.histplot(df['Fav genre'])
# Out:
# <Axes: xlabel='Fav genre', ylabel='Count'>

# %%
Display the anxiety distribution using a histogram

# %%
sns.histplot(df['Anxiety'])
# Out:
# <Axes: xlabel='Anxiety', ylabel='Count'>

# %% [markdown]
# Create a new data frame with only columns fav genre and anxiety but we want to keep only jazz in the fav genre column

# %%
df_jazz_anxiety = df[['Fav genre', 'Anxiety']]
df_jazz_anxiety
# Out:
#             Fav genre  Anxiety
# 0               Latin      3.0
# 1                Rock      7.0
# 2    Video game music      7.0
# 3                Jazz      9.0
# 4                 R&B      7.0
# ..                ...      ...
# 731              Rock      7.0
# 732               Pop      3.0
# 733               Rap      2.0
# 734         Classical      2.0
# 735           Hip hop      2.0
#
# [736 rows x 2 columns]

# %% [markdown]
# Filter to keep only Jazz in fav genre

# %%
df_jazz_anxiety = df_jazz_anxiety[df_jazz_anxiety['Fav genre'] == 'Jazz']
df_jazz_anxiety
# Out:
#     Fav genre  Anxiety
# 3        Jazz      9.0
# 5        Jazz      8.0
# 14       Jazz      6.0
# 75       Jazz      7.0
# 81       Jazz      3.0
# 86       Jazz      2.0
# 124      Jazz      7.0
# 146      Jazz      8.0
# 147      Jazz      5.0
# 283      Jazz      8.0
# 294      Jazz     10.0
# 347      Jazz      3.0
# 356      Jazz      9.0
# 417      Jazz      9.0
# 521      Jazz      7.0
# 529      Jazz      0.0
# 601      Jazz      2.0
# 618      Jazz      3.0
# 619      Jazz      6.0
# 673      Jazz      6.0

# %% [markdown]
# using a graph displaying the correlation between jazz and anxiety

# %%
sns.displot(df_jazz_anxiety)
